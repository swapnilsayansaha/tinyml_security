# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import torch
import argparse
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data.distributed
from torchvision import datasets, transforms
import math
from tqdm import tqdm
import json
import sys
from tinynas.nn.networks import ProxylessNASNets
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
config = tf.compat.v1.ConfigProto() 
config.gpu_options.allow_growth = True  
config.log_device_placement = True  
sess2 = tf.compat.v1.Session(config=config)
set_session(sess2) 
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
import onnx
from pytorch2keras.converter import pytorch_to_keras
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras.layers import Activation 
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
import tensorflow_datasets as tfds
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:21:00.0, compute capability: 8.6

# %% [markdown]
# ## Convert Pretrained Model from Pytorch to Tensorflow

# %%
with open('assets/configs/mcunet-320kb-1mb_imagenet.json') as f:
    config = json.load(f)
model = ProxylessNASNets.build_from_config(config)
model = model.to('cpu')
sd = torch.load('assets/pt_ckpt/mcunet-320kb-1mb_imagenet.pth', map_location='cpu')
model.load_state_dict(sd['state_dict'])
dummy_input = Variable(torch.randn(1,3, 176, 176))
k_model = pytorch_to_keras(model, dummy_input, [(3, 176, 176,)], verbose=True, change_ordering=True)
# Out:
# INFO:pytorch2keras:Converter is called.
# WARNING:pytorch2keras:Custom shapes isn't supported now.
# DEBUG:pytorch2keras:Input_names:
# DEBUG:pytorch2keras:['input_0']
# DEBUG:pytorch2keras:Output_names:
# DEBUG:pytorch2keras:['output_0']
# INFO:onnx2keras:Converter is called.
# DEBUG:onnx2keras:List input shapes:
# DEBUG:onnx2keras:[(3, 176, 176)]
# DEBUG:onnx2keras:List inputs:
# DEBUG:onnx2keras:Input 0 -> input_0.
# DEBUG:onnx2keras:List outputs:
# DEBUG:onnx2keras:Output 0 -> output_0.
# DEBUG:onnx2keras:Gathering weights to dictionary.
# DEBUG:onnx2keras:Found weight classifier.linear.weight with shape (1000, 160).
# DEBUG:onnx2keras:Found weight classifier.linear.bias with shape (1000,).
# DEBUG:onnx2keras:Found weight 486 with shape (16, 3, 3, 3).
# DEBUG:onnx2keras:Found weight 487 with shape (16,).
# DEBUG:onnx2keras:Found weight 489 with shape (16, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 490 with shape (16,).
# DEBUG:onnx2keras:Found weight 492 with shape (8, 16, 1, 1).
# DEBUG:onnx2keras:Found weight 493 with shape (8,).
# DEBUG:onnx2keras:Found weight 495 with shape (24, 8, 1, 1).
# DEBUG:onnx2keras:Found weight 496 with shape (24,).
# DEBUG:onnx2keras:Found weight 498 with shape (24, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 499 with shape (24,).
# DEBUG:onnx2keras:Found weight 501 with shape (16, 24, 1, 1).
# DEBUG:onnx2keras:Found weight 502 with shape (16,).
# DEBUG:onnx2keras:Found weight 504 with shape (80, 16, 1, 1).
# DEBUG:onnx2keras:Found weight 505 with shape (80,).
# DEBUG:onnx2keras:Found weight 507 with shape (80, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 508 with shape (80,).
# DEBUG:onnx2keras:Found weight 510 with shape (16, 80, 1, 1).
# DEBUG:onnx2keras:Found weight 511 with shape (16,).
# DEBUG:onnx2keras:Found weight 513 with shape (80, 16, 1, 1).
# DEBUG:onnx2keras:Found weight 514 with shape (80,).
# DEBUG:onnx2keras:Found weight 516 with shape (80, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 517 with shape (80,).
# DEBUG:onnx2keras:Found weight 519 with shape (16, 80, 1, 1).
# DEBUG:onnx2keras:Found weight 520 with shape (16,).
# DEBUG:onnx2keras:Found weight 522 with shape (64, 16, 1, 1).
# DEBUG:onnx2keras:Found weight 523 with shape (64,).
# DEBUG:onnx2keras:Found weight 525 with shape (64, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 526 with shape (64,).
# DEBUG:onnx2keras:Found weight 528 with shape (16, 64, 1, 1).
# DEBUG:onnx2keras:Found weight 529 with shape (16,).
# DEBUG:onnx2keras:Found weight 531 with shape (80, 16, 1, 1).
# DEBUG:onnx2keras:Found weight 532 with shape (80,).
# DEBUG:onnx2keras:Found weight 534 with shape (80, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 535 with shape (80,).
# DEBUG:onnx2keras:Found weight 537 with shape (24, 80, 1, 1).
# DEBUG:onnx2keras:Found weight 538 with shape (24,).
# DEBUG:onnx2keras:Found weight 540 with shape (120, 24, 1, 1).
# DEBUG:onnx2keras:Found weight 541 with shape (120,).
# DEBUG:onnx2keras:Found weight 543 with shape (120, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 544 with shape (120,).
# DEBUG:onnx2keras:Found weight 546 with shape (24, 120, 1, 1).
# DEBUG:onnx2keras:Found weight 547 with shape (24,).
# DEBUG:onnx2keras:Found weight 549 with shape (120, 24, 1, 1).
# DEBUG:onnx2keras:Found weight 550 with shape (120,).
# DEBUG:onnx2keras:Found weight 552 with shape (120, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 553 with shape (120,).
# DEBUG:onnx2keras:Found weight 555 with shape (24, 120, 1, 1).
# DEBUG:onnx2keras:Found weight 556 with shape (24,).
# DEBUG:onnx2keras:Found weight 558 with shape (120, 24, 1, 1).
# DEBUG:onnx2keras:Found weight 559 with shape (120,).
# DEBUG:onnx2keras:Found weight 561 with shape (120, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 562 with shape (120,).
# DEBUG:onnx2keras:Found weight 564 with shape (40, 120, 1, 1).
# DEBUG:onnx2keras:Found weight 565 with shape (40,).
# DEBUG:onnx2keras:Found weight 567 with shape (240, 40, 1, 1).
# DEBUG:onnx2keras:Found weight 568 with shape (240,).
# DEBUG:onnx2keras:Found weight 570 with shape (240, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 571 with shape (240,).
# DEBUG:onnx2keras:Found weight 573 with shape (40, 240, 1, 1).
# DEBUG:onnx2keras:Found weight 574 with shape (40,).
# DEBUG:onnx2keras:Found weight 576 with shape (160, 40, 1, 1).
# DEBUG:onnx2keras:Found weight 577 with shape (160,).
# DEBUG:onnx2keras:Found weight 579 with shape (160, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 580 with shape (160,).
# DEBUG:onnx2keras:Found weight 582 with shape (40, 160, 1, 1).
# DEBUG:onnx2keras:Found weight 583 with shape (40,).
# DEBUG:onnx2keras:Found weight 585 with shape (200, 40, 1, 1).
# DEBUG:onnx2keras:Found weight 586 with shape (200,).
# DEBUG:onnx2keras:Found weight 588 with shape (200, 1, 5, 5).
# DEBUG:onnx2keras:Found weight 589 with shape (200,).
# DEBUG:onnx2keras:Found weight 591 with shape (48, 200, 1, 1).
# DEBUG:onnx2keras:Found weight 592 with shape (48,).
# DEBUG:onnx2keras:Found weight 594 with shape (240, 48, 1, 1).
# DEBUG:onnx2keras:Found weight 595 with shape (240,).
# DEBUG:onnx2keras:Found weight 597 with shape (240, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 598 with shape (240,).
# DEBUG:onnx2keras:Found weight 600 with shape (48, 240, 1, 1).
# DEBUG:onnx2keras:Found weight 601 with shape (48,).
# DEBUG:onnx2keras:Found weight 603 with shape (240, 48, 1, 1).
# DEBUG:onnx2keras:Found weight 604 with shape (240,).
# DEBUG:onnx2keras:Found weight 606 with shape (240, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 607 with shape (240,).
# DEBUG:onnx2keras:Found weight 609 with shape (48, 240, 1, 1).
# DEBUG:onnx2keras:Found weight 610 with shape (48,).
# DEBUG:onnx2keras:Found weight 612 with shape (288, 48, 1, 1).
# DEBUG:onnx2keras:Found weight 613 with shape (288,).
# DEBUG:onnx2keras:Found weight 615 with shape (288, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 616 with shape (288,).
# DEBUG:onnx2keras:Found weight 618 with shape (96, 288, 1, 1).
# DEBUG:onnx2keras:Found weight 619 with shape (96,).
# DEBUG:onnx2keras:Found weight 621 with shape (480, 96, 1, 1).
# DEBUG:onnx2keras:Found weight 622 with shape (480,).
# DEBUG:onnx2keras:Found weight 624 with shape (480, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 625 with shape (480,).
# DEBUG:onnx2keras:Found weight 627 with shape (96, 480, 1, 1).
# DEBUG:onnx2keras:Found weight 628 with shape (96,).
# DEBUG:onnx2keras:Found weight 630 with shape (384, 96, 1, 1).
# DEBUG:onnx2keras:Found weight 631 with shape (384,).
# DEBUG:onnx2keras:Found weight 633 with shape (384, 1, 3, 3).
# DEBUG:onnx2keras:Found weight 634 with shape (384,).
# DEBUG:onnx2keras:Found weight 636 with shape (96, 384, 1, 1).
# DEBUG:onnx2keras:Found weight 637 with shape (96,).
# DEBUG:onnx2keras:Found weight 639 with shape (480, 96, 1, 1).
# DEBUG:onnx2keras:Found weight 640 with shape (480,).
# DEBUG:onnx2keras:Found weight 642 with shape (480, 1, 7, 7).
# DEBUG:onnx2keras:Found weight 643 with shape (480,).
# DEBUG:onnx2keras:Found weight 645 with shape (160, 480, 1, 1).
# DEBUG:onnx2keras:Found weight 646 with shape (160,).
# DEBUG:onnx2keras:Found input input_0 with shape (3, 176, 176)
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 485
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [2, 2], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name input_0).
# DEBUG:onnx2keras:Check input 1 (name 486).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 487).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 88, 88), dtype=tf.float32, name=None), name='485/BiasAdd:0', description="created by layer '485'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 329
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 485).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 88, 88), dtype=tf.float32, name=None), name='329/Relu6:0', description="created by layer '329'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 488
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 16, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 329).
# DEBUG:onnx2keras:Check input 1 (name 489).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 490).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 88, 88), dtype=tf.float32, name=None), name='488/BiasAdd:0', description="created by layer '488'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 332
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 488).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 88, 88), dtype=tf.float32, name=None), name='332/Relu6:0', description="created by layer '332'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 491
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 332).
# DEBUG:onnx2keras:Check input 1 (name 492).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 493).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 8, 88, 88), dtype=tf.float32, name=None), name='491/BiasAdd:0', description="created by layer '491'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 494
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 491).
# DEBUG:onnx2keras:Check input 1 (name 495).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 496).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 24, 88, 88), dtype=tf.float32, name=None), name='494/BiasAdd:0', description="created by layer '494'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 337
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 494).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 24, 88, 88), dtype=tf.float32, name=None), name='337/Relu6:0', description="created by layer '337'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 497
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 24, 'kernel_shape': [7, 7], 'pads': [3, 3, 3, 3], 'strides': [2, 2], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 337).
# DEBUG:onnx2keras:Check input 1 (name 498).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 499).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 24, 44, 44), dtype=tf.float32, name=None), name='497/BiasAdd:0', description="created by layer '497'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 340
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 497).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 24, 44, 44), dtype=tf.float32, name=None), name='340/Relu6:0', description="created by layer '340'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 500
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 340).
# DEBUG:onnx2keras:Check input 1 (name 501).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 502).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 16, 44, 44), dtype=tf.float32, name=None), name='500/BiasAdd:0', description="created by layer '500'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 503
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 500).
# DEBUG:onnx2keras:Check input 1 (name 504).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 505).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 80, 44, 44), dtype=tf.float32, name=None), name='503/BiasAdd:0', description="created by layer '503'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 345
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 503).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 80, 44, 44), dtype=tf.float32, name=None), name='345/Relu6:0', description="created by layer '345'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 506
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 80, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 345).
# DEBUG:onnx2keras:Check input 1 (name 507).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 508).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 80, 44, 44), dtype=tf.float32, name=None), name='506/BiasAdd:0', description="created by layer '506'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 348
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 506).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 80, 44, 44), dtype=tf.float32, name=None), name='348/Relu6:0', description="created by layer '348'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 509
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 348).
# DEBUG:onnx2keras:Check input 1 (name 510).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 511).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# graph(%input_0 : Float(1, 3, 176, 176, strides=[92928, 30976, 176, 1], requires_grad=0, device=cpu),
#       %classifier.linear.weight : Float(1000, 160, strides=[160, 1], requires_grad=1, device=cpu),
#       %classifier.linear.bias : Float(1000, strides=[1], requires_grad=1, device=cpu),
#       %486 : Float(16, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %487 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %489 : Float(16, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %490 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %492 : Float(8, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=0, device=cpu),
#       %493 : Float(8, strides=[1], requires_grad=0, device=cpu),
#       %495 : Float(24, 8, 1, 1, strides=[8, 1, 1, 1], requires_grad=0, device=cpu),
#       %496 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %498 : Float(24, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %499 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %501 : Float(16, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %502 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %504 : Float(80, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=0, device=cpu),
#       %505 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %507 : Float(80, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %508 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %510 : Float(16, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cpu),
#       %511 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %513 : Float(80, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=0, device=cpu),
#       %514 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %516 : Float(80, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %517 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %519 : Float(16, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cpu),
#       %520 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %522 : Float(64, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=0, device=cpu),
#       %523 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %525 : Float(64, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %526 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %528 : Float(16, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %529 : Float(16, strides=[1], requires_grad=0, device=cpu),
#       %531 : Float(80, 16, 1, 1, strides=[16, 1, 1, 1], requires_grad=0, device=cpu),
#       %532 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %534 : Float(80, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %535 : Float(80, strides=[1], requires_grad=0, device=cpu),
#       %537 : Float(24, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cpu),
#       %538 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %540 : Float(120, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %541 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %543 : Float(120, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %544 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %546 : Float(24, 120, 1, 1, strides=[120, 1, 1, 1], requires_grad=0, device=cpu),
#       %547 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %549 : Float(120, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %550 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %552 : Float(120, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %553 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %555 : Float(24, 120, 1, 1, strides=[120, 1, 1, 1], requires_grad=0, device=cpu),
#       %556 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %558 : Float(120, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %559 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %561 : Float(120, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %562 : Float(120, strides=[1], requires_grad=0, device=cpu),
#       %564 : Float(40, 120, 1, 1, strides=[120, 1, 1, 1], requires_grad=0, device=cpu),
#       %565 : Float(40, strides=[1], requires_grad=0, device=cpu),
#       %567 : Float(240, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=0, device=cpu),
#       %568 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %570 : Float(240, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %571 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %573 : Float(40, 240, 1, 1, strides=[240, 1, 1, 1], requires_grad=0, device=cpu),
#       %574 : Float(40, strides=[1], requires_grad=0, device=cpu),
#       %576 : Float(160, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=0, device=cpu),
#       %577 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %579 : Float(160, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %580 : Float(160, strides=[1], requires_grad=0, device=cpu),
#       %582 : Float(40, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cpu),
#       %583 : Float(40, strides=[1], requires_grad=0, device=cpu),
#       %585 : Float(200, 40, 1, 1, strides=[40, 1, 1, 1], requires_grad=0, device=cpu),
#       %586 : Float(200, strides=[1], requires_grad=0, device=cpu),
#       %588 : Float(200, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=0, device=cpu),
#       %589 : Float(200, strides=[1], requires_grad=0, device=cpu),
#       %591 : Float(48, 200, 1, 1, strides=[200, 1, 1, 1], requires_grad=0, device=cpu),
#       %592 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %594 : Float(240, 48, 1, 1, strides=[48, 1, 1, 1], requires_grad=0, device=cpu),
#       %595 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %597 : Float(240, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %598 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %600 : Float(48, 240, 1, 1, strides=[240, 1, 1, 1], requires_grad=0, device=cpu),
#       %601 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %603 : Float(240, 48, 1, 1, strides=[48, 1, 1, 1], requires_grad=0, device=cpu),
#       %604 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %606 : Float(240, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %607 : Float(240, strides=[1], requires_grad=0, device=cpu),
#       %609 : Float(48, 240, 1, 1, strides=[240, 1, 1, 1], requires_grad=0, device=cpu),
#       %610 : Float(48, strides=[1], requires_grad=0, device=cpu),
#       %612 : Float(288, 48, 1, 1, strides=[48, 1, 1, 1], requires_grad=0, device=cpu),
#       %613 : Float(288, strides=[1], requires_grad=0, device=cpu),
#       %615 : Float(288, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %616 : Float(288, strides=[1], requires_grad=0, device=cpu),
#       %618 : Float(96, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cpu),
#       %619 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %621 : Float(480, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %622 : Float(480, strides=[1], requires_grad=0, device=cpu),
#       %624 : Float(480, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %625 : Float(480, strides=[1], requires_grad=0, device=cpu),
#       %627 : Float(96, 480, 1, 1, strides=[480, 1, 1, 1], requires_grad=0, device=cpu),
#       %628 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %630 : Float(384, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %631 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %633 : Float(384, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %634 : Float(384, strides=[1], requires_grad=0, device=cpu),
#       %636 : Float(96, 384, 1, 1, strides=[384, 1, 1, 1], requires_grad=0, device=cpu),
#       %637 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %639 : Float(480, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %640 : Float(480, strides=[1], requires_grad=0, device=cpu),
#       %642 : Float(480, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cpu),
#       %643 : Float(480, strides=[1], requires_grad=0, device=cpu),
#       %645 : Float(160, 480, 1, 1, strides=[480, 1, 1, 1], requires_grad=0, device=cpu),
#       %646 : Float(160, strides=[1], requires_grad=0, device=cpu)):
#   %485 : Float(1, 16, 88, 88, strides=[123904, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%input_0, %486, %487)
#   %329 : Float(1, 16, 88, 88, strides=[123904, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%485) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %488 : Float(1, 16, 88, 88, strides=[123904, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=16, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%329, %489, %490)
#   %332 : Float(1, 16, 88, 88, strides=[123904, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%488) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %491 : Float(1, 8, 88, 88, strides=[61952, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%332, %492, %493)
#   %494 : Float(1, 24, 88, 88, strides=[185856, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%491, %495, %496)
#   %337 : Float(1, 24, 88, 88, strides=[185856, 7744, 88, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%494) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %497 : Float(1, 24, 44, 44, strides=[46464, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=24, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%337, %498, %499)
#   %340 : Float(1, 24, 44, 44, strides=[46464, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%497) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %500 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%340, %501, %502)
#   %503 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%500, %504, %505)
#   %345 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%503) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %506 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=80, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%345, %507, %508)
#   %348 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%506) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %509 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%348, %510, %511)
#   %351 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Add(%509, %500) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %512 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%351, %513, %514)
#   %354 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%512) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %515 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=80, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[1, 1]](%354, %516, %517)
#   %357 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%515) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %518 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%357, %519, %520)
#   %360 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Add(%518, %351) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %521 : Float(1, 64, 44, 44, strides=[123904, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%360, %522, %523)
#   %363 : Float(1, 64, 44, 44, strides=[123904, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%521) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %524 : Float(1, 64, 44, 44, strides=[123904, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=64, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%363, %525, %526)
#   %366 : Float(1, 64, 44, 44, strides=[123904, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%524) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %527 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%366, %528, %529)
#   %369 : Float(1, 16, 44, 44, strides=[30976, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Add(%527, %360) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %530 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%369, %531, %532)
#   %372 : Float(1, 80, 44, 44, strides=[154880, 1936, 44, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%530) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %533 : Float(1, 80, 22, 22, strides=[38720, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=80, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[2, 2]](%372, %534, %535)
#   %375 : Float(1, 80, 22, 22, strides=[38720, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%533) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %536 : Float(1, 24, 22, 22, strides=[11616, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%375, %537, %538)
#   %539 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%536, %540, %541)
#   %380 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%539) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %542 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=120, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%380, %543, %544)
#   %383 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%542) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %545 : Float(1, 24, 22, 22, strides=[11616, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%383, %546, %547)
#   %386 : Float(1, 24, 22, 22, strides=[11616, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Add(%545, %536) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %548 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%386, %549, %550)
#   %389 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%548) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %551 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=120, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%389, %552, %553)
#   %392 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%551) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %554 : Float(1, 24, 22, 22, strides=[11616, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%392, %555, %556)
#   %395 : Float(1, 24, 22, 22, strides=[11616, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Add(%554, %386) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %557 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%395, %558, %559)
#   %398 : Float(1, 120, 22, 22, strides=[58080, 484, 22, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%557) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %560 : Float(1, 120, 11, 11, strides=[14520, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=120, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%398, %561, %562)
#   %401 : Float(1, 120, 11, 11, strides=[14520, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%560) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %563 : Float(1, 40, 11, 11, strides=[4840, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%401, %564, %565)
#   %566 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%563, %567, %568)
#   %406 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%566) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %569 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=240, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[1, 1]](%406, %570, %571)
#   %409 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%569) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %572 : Float(1, 40, 11, 11, strides=[4840, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%409, %573, %574)
#   %412 : Float(1, 40, 11, 11, strides=[4840, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Add(%572, %563) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %575 : Float(1, 160, 11, 11, strides=[19360, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%412, %576, %577)
#   %415 : Float(1, 160, 11, 11, strides=[19360, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%575) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %578 : Float(1, 160, 11, 11, strides=[19360, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=160, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%415, %579, %580)
#   %418 : Float(1, 160, 11, 11, strides=[19360, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%578) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %581 : Float(1, 40, 11, 11, strides=[4840, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%418, %582, %583)
#   %421 : Float(1, 40, 11, 11, strides=[4840, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Add(%581, %412) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %584 : Float(1, 200, 11, 11, strides=[24200, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%421, %585, %586)
#   %424 : Float(1, 200, 11, 11, strides=[24200, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%584) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %587 : Float(1, 200, 11, 11, strides=[24200, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=200, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%424, %588, %589)
#   %427 : Float(1, 200, 11, 11, strides=[24200, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%587) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %590 : Float(1, 48, 11, 11, strides=[5808, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%427, %591, %592)
#   %593 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%590, %594, %595)
#   %432 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%593) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %596 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=240, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[1, 1]](%432, %597, %598)
#   %435 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%596) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %599 : Float(1, 48, 11, 11, strides=[5808, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%435, %600, %601)
#   %438 : Float(1, 48, 11, 11, strides=[5808, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Add(%599, %590) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %602 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%438, %603, %604)
#   %441 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%602) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %605 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=240, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%441, %606, %607)
#   %444 : Float(1, 240, 11, 11, strides=[29040, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%605) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %608 : Float(1, 48, 11, 11, strides=[5808, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%444, %609, %610)
#   %447 : Float(1, 48, 11, 11, strides=[5808, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Add(%608, %438) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %611 : Float(1, 288, 11, 11, strides=[34848, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%447, %612, %613)
#   %450 : Float(1, 288, 11, 11, strides=[34848, 121, 11, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%611) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %614 : Float(1, 288, 6, 6, strides=[10368, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=288, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%450, %615, %616)
#   %453 : Float(1, 288, 6, 6, strides=[10368, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%614) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %617 : Float(1, 96, 6, 6, strides=[3456, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%453, %618, %619)
#   %620 : Float(1, 480, 6, 6, strides=[17280, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%617, %621, %622)
#   %458 : Float(1, 480, 6, 6, strides=[17280, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%620) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %623 : Float(1, 480, 6, 6, strides=[17280, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=480, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[1, 1]](%458, %624, %625)
#   %461 : Float(1, 480, 6, 6, strides=[17280, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%623) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
#   %626 : Float(1, 96, 6, 6, strides=[3456, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%461, %627, %628)
#   %464 : Float(1, 96, 6, 6, strides=[3456, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Add(%626, %617) # /home/nesl/209as_sec/cifar10/TinyML Models/mcunet/tinynas/nn/networks/proxyless_nets.py:49:0
#   %629 : Float(1, 384, 6, 6, strides=[13824, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%464, %630, %631)
#   %467 : Float(1, 384, 6, 6, strides=[13824, 36, 6, 1], requires_grad=1, device=cpu) = onnx::Clip[max=6., min=0.](%629) # /home/nesl/swapnil_debug/lib/python3.8/site-packages/torch/nn/functional.py:1348:0
# ...
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 623
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 480, 'kernel_shape': [7, 7], 'pads': [3, 3, 3, 3], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 458).
# DEBUG:onnx2keras:Check input 1 (name 624).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 625).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='623/BiasAdd:0', description="created by layer '623'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 461
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 623).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='461/Relu6:0', description="created by layer '461'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 626
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 461).
# DEBUG:onnx2keras:Check input 1 (name 627).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 628).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 96, 6, 6), dtype=tf.float32, name=None), name='626/BiasAdd:0', description="created by layer '626'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 464
# DEBUG:onnx2keras:node_params: {'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 626).
# DEBUG:onnx2keras:Check input 1 (name 617).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:add:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 96, 6, 6), dtype=tf.float32, name=None), name='464/add:0', description="created by layer '464'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 629
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 464).
# DEBUG:onnx2keras:Check input 1 (name 630).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 631).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 384, 6, 6), dtype=tf.float32, name=None), name='629/BiasAdd:0', description="created by layer '629'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 467
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 629).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 384, 6, 6), dtype=tf.float32, name=None), name='467/Relu6:0', description="created by layer '467'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 632
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 384, 'kernel_shape': [3, 3], 'pads': [1, 1, 1, 1], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 467).
# DEBUG:onnx2keras:Check input 1 (name 633).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 634).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 384, 6, 6), dtype=tf.float32, name=None), name='632/BiasAdd:0', description="created by layer '632'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 470
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 632).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 384, 6, 6), dtype=tf.float32, name=None), name='470/Relu6:0', description="created by layer '470'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 635
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 470).
# DEBUG:onnx2keras:Check input 1 (name 636).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 637).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 96, 6, 6), dtype=tf.float32, name=None), name='635/BiasAdd:0', description="created by layer '635'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Add
# DEBUG:onnx2keras:node_name: 473
# DEBUG:onnx2keras:node_params: {'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 635).
# DEBUG:onnx2keras:Check input 1 (name 464).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:add:Convert inputs to Keras/TF layers if needed.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 96, 6, 6), dtype=tf.float32, name=None), name='473/add:0', description="created by layer '473'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 638
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 473).
# DEBUG:onnx2keras:Check input 1 (name 639).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 640).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='638/BiasAdd:0', description="created by layer '638'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 476
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 638).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='476/Relu6:0', description="created by layer '476'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 641
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 480, 'kernel_shape': [7, 7], 'pads': [3, 3, 3, 3], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 476).
# DEBUG:onnx2keras:Check input 1 (name 642).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 643).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# DEBUG:onnx2keras:conv:Number of groups is equal to input channels, use DepthWise convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='641/BiasAdd:0', description="created by layer '641'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Clip
# DEBUG:onnx2keras:node_name: 479
# DEBUG:onnx2keras:node_params: {'max': 6.0, 'min': 0.0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 641).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:clip:Using ReLU(6.0) instead of clip
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 480, 6, 6), dtype=tf.float32, name=None), name='479/Relu6:0', description="created by layer '479'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: 644
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [1, 1], 'pads': [0, 0, 0, 0], 'strides': [1, 1], 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 479).
# DEBUG:onnx2keras:Check input 1 (name 645).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name 646).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 160, 6, 6), dtype=tf.float32, name=None), name='644/BiasAdd:0', description="created by layer '644'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: ReduceMean
# DEBUG:onnx2keras:node_name: 482
# DEBUG:onnx2keras:node_params: {'axes': [3], 'keepdims': 0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 644).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 160, 6), dtype=tf.float32, name=None), name='482/Mean:0', description="created by layer '482'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: ReduceMean
# DEBUG:onnx2keras:node_name: 483
# DEBUG:onnx2keras:node_params: {'axes': [2], 'keepdims': 0, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 482).
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 160), dtype=tf.float32, name=None), name='483/Mean:0', description="created by layer '483'")
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Gemm
# DEBUG:onnx2keras:node_name: output_0
# DEBUG:onnx2keras:node_params: {'alpha': 1.0, 'beta': 1.0, 'transB': 1, 'change_ordering': True, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name 483).
# DEBUG:onnx2keras:Check input 1 (name classifier.linear.weight).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name classifier.linear.bias).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:gemm:Convert GEMM with bias.
# DEBUG:onnx2keras:gemm:Transposing W matrix.
# DEBUG:onnx2keras:gemm:Input units 160, output units 1000.
# DEBUG:onnx2keras:Output TF Layer -> KerasTensor(type_spec=TensorSpec(shape=(None, 1000), dtype=tf.float32, name=None), name='output_0/BiasAdd:0', description="created by layer 'output_0'")

# %%
k_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_0 (InputLayer)            [(None, 176, 176, 3) 0
# __________________________________________________________________________________________________
# 485_pad (ZeroPadding2D)         (None, 178, 178, 3)  0           input_0[0][0]
# __________________________________________________________________________________________________
# 485 (Conv2D)                    (None, 88, 88, 16)   448         485_pad[0][0]
# __________________________________________________________________________________________________
# 329 (ReLU)                      (None, 88, 88, 16)   0           485[0][0]
# __________________________________________________________________________________________________
# 488_pad (ZeroPadding2D)         (None, 90, 90, 16)   0           329[0][0]
# __________________________________________________________________________________________________
# 488 (DepthwiseConv2D)           (None, 88, 88, 16)   160         488_pad[0][0]
# __________________________________________________________________________________________________
# 332 (ReLU)                      (None, 88, 88, 16)   0           488[0][0]
# __________________________________________________________________________________________________
# 491 (Conv2D)                    (None, 88, 88, 8)    136         332[0][0]
# __________________________________________________________________________________________________
# 494 (Conv2D)                    (None, 88, 88, 24)   216         491[0][0]
# __________________________________________________________________________________________________
# 337 (ReLU)                      (None, 88, 88, 24)   0           494[0][0]
# __________________________________________________________________________________________________
# 497_pad (ZeroPadding2D)         (None, 94, 94, 24)   0           337[0][0]
# __________________________________________________________________________________________________
# 497 (DepthwiseConv2D)           (None, 44, 44, 24)   1200        497_pad[0][0]
# __________________________________________________________________________________________________
# 340 (ReLU)                      (None, 44, 44, 24)   0           497[0][0]
# __________________________________________________________________________________________________
# 500 (Conv2D)                    (None, 44, 44, 16)   400         340[0][0]
# __________________________________________________________________________________________________
# 503 (Conv2D)                    (None, 44, 44, 80)   1360        500[0][0]
# __________________________________________________________________________________________________
# 345 (ReLU)                      (None, 44, 44, 80)   0           503[0][0]
# __________________________________________________________________________________________________
# 506_pad (ZeroPadding2D)         (None, 46, 46, 80)   0           345[0][0]
# __________________________________________________________________________________________________
# 506 (DepthwiseConv2D)           (None, 44, 44, 80)   800         506_pad[0][0]
# __________________________________________________________________________________________________
# 348 (ReLU)                      (None, 44, 44, 80)   0           506[0][0]
# __________________________________________________________________________________________________
# 509 (Conv2D)                    (None, 44, 44, 16)   1296        348[0][0]
# __________________________________________________________________________________________________
# 351 (Add)                       (None, 44, 44, 16)   0           509[0][0]
#                                                                  500[0][0]
# __________________________________________________________________________________________________
# 512 (Conv2D)                    (None, 44, 44, 80)   1360        351[0][0]
# __________________________________________________________________________________________________
# 354 (ReLU)                      (None, 44, 44, 80)   0           512[0][0]
# __________________________________________________________________________________________________
# 515_pad (ZeroPadding2D)         (None, 50, 50, 80)   0           354[0][0]
# __________________________________________________________________________________________________
# 515 (DepthwiseConv2D)           (None, 44, 44, 80)   4000        515_pad[0][0]
# __________________________________________________________________________________________________
# 357 (ReLU)                      (None, 44, 44, 80)   0           515[0][0]
# __________________________________________________________________________________________________
# 518 (Conv2D)                    (None, 44, 44, 16)   1296        357[0][0]
# __________________________________________________________________________________________________
# 360 (Add)                       (None, 44, 44, 16)   0           518[0][0]
#                                                                  351[0][0]
# __________________________________________________________________________________________________
# 521 (Conv2D)                    (None, 44, 44, 64)   1088        360[0][0]
# __________________________________________________________________________________________________
# 363 (ReLU)                      (None, 44, 44, 64)   0           521[0][0]
# __________________________________________________________________________________________________
# 524_pad (ZeroPadding2D)         (None, 48, 48, 64)   0           363[0][0]
# __________________________________________________________________________________________________
# 524 (DepthwiseConv2D)           (None, 44, 44, 64)   1664        524_pad[0][0]
# __________________________________________________________________________________________________
# 366 (ReLU)                      (None, 44, 44, 64)   0           524[0][0]
# __________________________________________________________________________________________________
# 527 (Conv2D)                    (None, 44, 44, 16)   1040        366[0][0]
# __________________________________________________________________________________________________
# 369 (Add)                       (None, 44, 44, 16)   0           527[0][0]
#                                                                  360[0][0]
# __________________________________________________________________________________________________
# 530 (Conv2D)                    (None, 44, 44, 80)   1360        369[0][0]
# __________________________________________________________________________________________________
# 372 (ReLU)                      (None, 44, 44, 80)   0           530[0][0]
# __________________________________________________________________________________________________
# 533_pad (ZeroPadding2D)         (None, 48, 48, 80)   0           372[0][0]
# __________________________________________________________________________________________________
# 533 (DepthwiseConv2D)           (None, 22, 22, 80)   2080        533_pad[0][0]
# __________________________________________________________________________________________________
# 375 (ReLU)                      (None, 22, 22, 80)   0           533[0][0]
# __________________________________________________________________________________________________
# 536 (Conv2D)                    (None, 22, 22, 24)   1944        375[0][0]
# __________________________________________________________________________________________________
# 539 (Conv2D)                    (None, 22, 22, 120)  3000        536[0][0]
# __________________________________________________________________________________________________
# 380 (ReLU)                      (None, 22, 22, 120)  0           539[0][0]
# __________________________________________________________________________________________________
# 542_pad (ZeroPadding2D)         (None, 26, 26, 120)  0           380[0][0]
# __________________________________________________________________________________________________
# 542 (DepthwiseConv2D)           (None, 22, 22, 120)  3120        542_pad[0][0]
# __________________________________________________________________________________________________
# 383 (ReLU)                      (None, 22, 22, 120)  0           542[0][0]
# __________________________________________________________________________________________________
# 545 (Conv2D)                    (None, 22, 22, 24)   2904        383[0][0]
# __________________________________________________________________________________________________
# 386 (Add)                       (None, 22, 22, 24)   0           545[0][0]
#                                                                  536[0][0]
# __________________________________________________________________________________________________
# 548 (Conv2D)                    (None, 22, 22, 120)  3000        386[0][0]
# __________________________________________________________________________________________________
# 389 (ReLU)                      (None, 22, 22, 120)  0           548[0][0]
# __________________________________________________________________________________________________
# 551_pad (ZeroPadding2D)         (None, 26, 26, 120)  0           389[0][0]
# __________________________________________________________________________________________________
# 551 (DepthwiseConv2D)           (None, 22, 22, 120)  3120        551_pad[0][0]
# __________________________________________________________________________________________________
# 392 (ReLU)                      (None, 22, 22, 120)  0           551[0][0]
# __________________________________________________________________________________________________
# 554 (Conv2D)                    (None, 22, 22, 24)   2904        392[0][0]
# __________________________________________________________________________________________________
# 395 (Add)                       (None, 22, 22, 24)   0           554[0][0]
#                                                                  386[0][0]
# __________________________________________________________________________________________________
# 557 (Conv2D)                    (None, 22, 22, 120)  3000        395[0][0]
# __________________________________________________________________________________________________
# 398 (ReLU)                      (None, 22, 22, 120)  0           557[0][0]
# __________________________________________________________________________________________________
# 560_pad (ZeroPadding2D)         (None, 24, 24, 120)  0           398[0][0]
# __________________________________________________________________________________________________
# 560 (DepthwiseConv2D)           (None, 11, 11, 120)  1200        560_pad[0][0]
# __________________________________________________________________________________________________
# 401 (ReLU)                      (None, 11, 11, 120)  0           560[0][0]
# __________________________________________________________________________________________________
# 563 (Conv2D)                    (None, 11, 11, 40)   4840        401[0][0]
# __________________________________________________________________________________________________
# 566 (Conv2D)                    (None, 11, 11, 240)  9840        563[0][0]
# __________________________________________________________________________________________________
# 406 (ReLU)                      (None, 11, 11, 240)  0           566[0][0]
# __________________________________________________________________________________________________
# 569_pad (ZeroPadding2D)         (None, 17, 17, 240)  0           406[0][0]
# __________________________________________________________________________________________________
# 569 (DepthwiseConv2D)           (None, 11, 11, 240)  12000       569_pad[0][0]
# __________________________________________________________________________________________________
# 409 (ReLU)                      (None, 11, 11, 240)  0           569[0][0]
# __________________________________________________________________________________________________
# 572 (Conv2D)                    (None, 11, 11, 40)   9640        409[0][0]
# __________________________________________________________________________________________________
# 412 (Add)                       (None, 11, 11, 40)   0           572[0][0]
#                                                                  563[0][0]
# __________________________________________________________________________________________________
# 575 (Conv2D)                    (None, 11, 11, 160)  6560        412[0][0]
# __________________________________________________________________________________________________
# 415 (ReLU)                      (None, 11, 11, 160)  0           575[0][0]
# __________________________________________________________________________________________________
# 578_pad (ZeroPadding2D)         (None, 15, 15, 160)  0           415[0][0]
# __________________________________________________________________________________________________
# 578 (DepthwiseConv2D)           (None, 11, 11, 160)  4160        578_pad[0][0]
# __________________________________________________________________________________________________
# 418 (ReLU)                      (None, 11, 11, 160)  0           578[0][0]
# __________________________________________________________________________________________________
# 581 (Conv2D)                    (None, 11, 11, 40)   6440        418[0][0]
# __________________________________________________________________________________________________
# 421 (Add)                       (None, 11, 11, 40)   0           581[0][0]
#                                                                  412[0][0]
# __________________________________________________________________________________________________
# 584 (Conv2D)                    (None, 11, 11, 200)  8200        421[0][0]
# __________________________________________________________________________________________________
# 424 (ReLU)                      (None, 11, 11, 200)  0           584[0][0]
# __________________________________________________________________________________________________
# 587_pad (ZeroPadding2D)         (None, 15, 15, 200)  0           424[0][0]
# __________________________________________________________________________________________________
# 587 (DepthwiseConv2D)           (None, 11, 11, 200)  5200        587_pad[0][0]
# __________________________________________________________________________________________________
# 427 (ReLU)                      (None, 11, 11, 200)  0           587[0][0]
# __________________________________________________________________________________________________
# 590 (Conv2D)                    (None, 11, 11, 48)   9648        427[0][0]
# __________________________________________________________________________________________________
# 593 (Conv2D)                    (None, 11, 11, 240)  11760       590[0][0]
# __________________________________________________________________________________________________
# 432 (ReLU)                      (None, 11, 11, 240)  0           593[0][0]
# __________________________________________________________________________________________________
# 596_pad (ZeroPadding2D)         (None, 17, 17, 240)  0           432[0][0]
# __________________________________________________________________________________________________
# 596 (DepthwiseConv2D)           (None, 11, 11, 240)  12000       596_pad[0][0]
# __________________________________________________________________________________________________
# 435 (ReLU)                      (None, 11, 11, 240)  0           596[0][0]
# __________________________________________________________________________________________________
# 599 (Conv2D)                    (None, 11, 11, 48)   11568       435[0][0]
# __________________________________________________________________________________________________
# 438 (Add)                       (None, 11, 11, 48)   0           599[0][0]
#                                                                  590[0][0]
# __________________________________________________________________________________________________
# 602 (Conv2D)                    (None, 11, 11, 240)  11760       438[0][0]
# __________________________________________________________________________________________________
# 441 (ReLU)                      (None, 11, 11, 240)  0           602[0][0]
# __________________________________________________________________________________________________
# 605_pad (ZeroPadding2D)         (None, 13, 13, 240)  0           441[0][0]
# __________________________________________________________________________________________________
# 605 (DepthwiseConv2D)           (None, 11, 11, 240)  2400        605_pad[0][0]
# __________________________________________________________________________________________________
# 444 (ReLU)                      (None, 11, 11, 240)  0           605[0][0]
# __________________________________________________________________________________________________
# 608 (Conv2D)                    (None, 11, 11, 48)   11568       444[0][0]
# __________________________________________________________________________________________________
# 447 (Add)                       (None, 11, 11, 48)   0           608[0][0]
#                                                                  438[0][0]
# __________________________________________________________________________________________________
# 611 (Conv2D)                    (None, 11, 11, 288)  14112       447[0][0]
# __________________________________________________________________________________________________
# 450 (ReLU)                      (None, 11, 11, 288)  0           611[0][0]
# __________________________________________________________________________________________________
# 614_pad (ZeroPadding2D)         (None, 13, 13, 288)  0           450[0][0]
# __________________________________________________________________________________________________
# 614 (DepthwiseConv2D)           (None, 6, 6, 288)    2880        614_pad[0][0]
# __________________________________________________________________________________________________
# 453 (ReLU)                      (None, 6, 6, 288)    0           614[0][0]
# __________________________________________________________________________________________________
# 617 (Conv2D)                    (None, 6, 6, 96)     27744       453[0][0]
# __________________________________________________________________________________________________
# 620 (Conv2D)                    (None, 6, 6, 480)    46560       617[0][0]
# __________________________________________________________________________________________________
# 458 (ReLU)                      (None, 6, 6, 480)    0           620[0][0]
# __________________________________________________________________________________________________
# 623_pad (ZeroPadding2D)         (None, 12, 12, 480)  0           458[0][0]
# __________________________________________________________________________________________________
# 623 (DepthwiseConv2D)           (None, 6, 6, 480)    24000       623_pad[0][0]
# __________________________________________________________________________________________________
# 461 (ReLU)                      (None, 6, 6, 480)    0           623[0][0]
# __________________________________________________________________________________________________
# 626 (Conv2D)                    (None, 6, 6, 96)     46176       461[0][0]
# __________________________________________________________________________________________________
# 464 (Add)                       (None, 6, 6, 96)     0           626[0][0]
#                                                                  617[0][0]
# __________________________________________________________________________________________________
# 629 (Conv2D)                    (None, 6, 6, 384)    37248       464[0][0]
# __________________________________________________________________________________________________
# 467 (ReLU)                      (None, 6, 6, 384)    0           629[0][0]
# __________________________________________________________________________________________________
# 632_pad (ZeroPadding2D)         (None, 8, 8, 384)    0           467[0][0]
# __________________________________________________________________________________________________
# 632 (DepthwiseConv2D)           (None, 6, 6, 384)    3840        632_pad[0][0]
# __________________________________________________________________________________________________
# 470 (ReLU)                      (None, 6, 6, 384)    0           632[0][0]
# __________________________________________________________________________________________________
# 635 (Conv2D)                    (None, 6, 6, 96)     36960       470[0][0]
# __________________________________________________________________________________________________
# 473 (Add)                       (None, 6, 6, 96)     0           635[0][0]
#                                                                  464[0][0]
# __________________________________________________________________________________________________
# 638 (Conv2D)                    (None, 6, 6, 480)    46560       473[0][0]
# __________________________________________________________________________________________________
# 476 (ReLU)                      (None, 6, 6, 480)    0           638[0][0]
# __________________________________________________________________________________________________
# 641_pad (ZeroPadding2D)         (None, 12, 12, 480)  0           476[0][0]
# __________________________________________________________________________________________________
# 641 (DepthwiseConv2D)           (None, 6, 6, 480)    24000       641_pad[0][0]
# __________________________________________________________________________________________________
# 479 (ReLU)                      (None, 6, 6, 480)    0           641[0][0]
# __________________________________________________________________________________________________
# 644 (Conv2D)                    (None, 6, 6, 160)    76960       479[0][0]
# __________________________________________________________________________________________________
# 482 (Lambda)                    (None, 6, 160)       0           644[0][0]
# __________________________________________________________________________________________________
# 483 (Lambda)                    (None, 160)          0           482[0][0]
# __________________________________________________________________________________________________
# output_0 (Dense)                (None, 1000)         161000      483[0][0]
# ==================================================================================================
# Total params: 729,720
# Trainable params: 729,720
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Import Dataset

# %%
dataset_name = "cifar10"
(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train", "test"], with_info=True, as_supervised=True
)
NUM_CLASSES = ds_info.features["label"].num_classes

IMG_SIZE = 176
batch_size = 50
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)
# Out:
# INFO:absl:Load dataset info from /home/nesl/tensorflow_datasets/cifar10/3.0.2
# INFO:absl:Reusing dataset cifar10 (/home/nesl/tensorflow_datasets/cifar10/3.0.2)
# INFO:absl:Constructing tf.data.Dataset cifar10 for split ['train', 'test'], from /home/nesl/tensorflow_datasets/cifar10/3.0.2

# %% [markdown]
# ## Transfer Learning

# %%
x = k_model.layers[-4].output
x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.2, name="top_dropout")(x)
outputs = layers.Dense(10, activation="softmax", name="pred")(x)
model = Model(inputs = k_model.input, outputs = outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_0 (InputLayer)            [(None, 176, 176, 3) 0
# __________________________________________________________________________________________________
# 485_pad (ZeroPadding2D)         (None, 178, 178, 3)  0           input_0[0][0]
# __________________________________________________________________________________________________
# 485 (Conv2D)                    (None, 88, 88, 16)   448         485_pad[0][0]
# __________________________________________________________________________________________________
# 329 (ReLU)                      (None, 88, 88, 16)   0           485[0][0]
# __________________________________________________________________________________________________
# 488_pad (ZeroPadding2D)         (None, 90, 90, 16)   0           329[0][0]
# __________________________________________________________________________________________________
# 488 (DepthwiseConv2D)           (None, 88, 88, 16)   160         488_pad[0][0]
# __________________________________________________________________________________________________
# 332 (ReLU)                      (None, 88, 88, 16)   0           488[0][0]
# __________________________________________________________________________________________________
# 491 (Conv2D)                    (None, 88, 88, 8)    136         332[0][0]
# __________________________________________________________________________________________________
# 494 (Conv2D)                    (None, 88, 88, 24)   216         491[0][0]
# __________________________________________________________________________________________________
# 337 (ReLU)                      (None, 88, 88, 24)   0           494[0][0]
# __________________________________________________________________________________________________
# 497_pad (ZeroPadding2D)         (None, 94, 94, 24)   0           337[0][0]
# __________________________________________________________________________________________________
# 497 (DepthwiseConv2D)           (None, 44, 44, 24)   1200        497_pad[0][0]
# __________________________________________________________________________________________________
# 340 (ReLU)                      (None, 44, 44, 24)   0           497[0][0]
# __________________________________________________________________________________________________
# 500 (Conv2D)                    (None, 44, 44, 16)   400         340[0][0]
# __________________________________________________________________________________________________
# 503 (Conv2D)                    (None, 44, 44, 80)   1360        500[0][0]
# __________________________________________________________________________________________________
# 345 (ReLU)                      (None, 44, 44, 80)   0           503[0][0]
# __________________________________________________________________________________________________
# 506_pad (ZeroPadding2D)         (None, 46, 46, 80)   0           345[0][0]
# __________________________________________________________________________________________________
# 506 (DepthwiseConv2D)           (None, 44, 44, 80)   800         506_pad[0][0]
# __________________________________________________________________________________________________
# 348 (ReLU)                      (None, 44, 44, 80)   0           506[0][0]
# __________________________________________________________________________________________________
# 509 (Conv2D)                    (None, 44, 44, 16)   1296        348[0][0]
# __________________________________________________________________________________________________
# 351 (Add)                       (None, 44, 44, 16)   0           509[0][0]
#                                                                  500[0][0]
# __________________________________________________________________________________________________
# 512 (Conv2D)                    (None, 44, 44, 80)   1360        351[0][0]
# __________________________________________________________________________________________________
# 354 (ReLU)                      (None, 44, 44, 80)   0           512[0][0]
# __________________________________________________________________________________________________
# 515_pad (ZeroPadding2D)         (None, 50, 50, 80)   0           354[0][0]
# __________________________________________________________________________________________________
# 515 (DepthwiseConv2D)           (None, 44, 44, 80)   4000        515_pad[0][0]
# __________________________________________________________________________________________________
# 357 (ReLU)                      (None, 44, 44, 80)   0           515[0][0]
# __________________________________________________________________________________________________
# 518 (Conv2D)                    (None, 44, 44, 16)   1296        357[0][0]
# __________________________________________________________________________________________________
# 360 (Add)                       (None, 44, 44, 16)   0           518[0][0]
#                                                                  351[0][0]
# __________________________________________________________________________________________________
# 521 (Conv2D)                    (None, 44, 44, 64)   1088        360[0][0]
# __________________________________________________________________________________________________
# 363 (ReLU)                      (None, 44, 44, 64)   0           521[0][0]
# __________________________________________________________________________________________________
# 524_pad (ZeroPadding2D)         (None, 48, 48, 64)   0           363[0][0]
# __________________________________________________________________________________________________
# 524 (DepthwiseConv2D)           (None, 44, 44, 64)   1664        524_pad[0][0]
# __________________________________________________________________________________________________
# 366 (ReLU)                      (None, 44, 44, 64)   0           524[0][0]
# __________________________________________________________________________________________________
# 527 (Conv2D)                    (None, 44, 44, 16)   1040        366[0][0]
# __________________________________________________________________________________________________
# 369 (Add)                       (None, 44, 44, 16)   0           527[0][0]
#                                                                  360[0][0]
# __________________________________________________________________________________________________
# 530 (Conv2D)                    (None, 44, 44, 80)   1360        369[0][0]
# __________________________________________________________________________________________________
# 372 (ReLU)                      (None, 44, 44, 80)   0           530[0][0]
# __________________________________________________________________________________________________
# 533_pad (ZeroPadding2D)         (None, 48, 48, 80)   0           372[0][0]
# __________________________________________________________________________________________________
# 533 (DepthwiseConv2D)           (None, 22, 22, 80)   2080        533_pad[0][0]
# __________________________________________________________________________________________________
# 375 (ReLU)                      (None, 22, 22, 80)   0           533[0][0]
# __________________________________________________________________________________________________
# 536 (Conv2D)                    (None, 22, 22, 24)   1944        375[0][0]
# __________________________________________________________________________________________________
# 539 (Conv2D)                    (None, 22, 22, 120)  3000        536[0][0]
# __________________________________________________________________________________________________
# 380 (ReLU)                      (None, 22, 22, 120)  0           539[0][0]
# __________________________________________________________________________________________________
# 542_pad (ZeroPadding2D)         (None, 26, 26, 120)  0           380[0][0]
# __________________________________________________________________________________________________
# 542 (DepthwiseConv2D)           (None, 22, 22, 120)  3120        542_pad[0][0]
# __________________________________________________________________________________________________
# 383 (ReLU)                      (None, 22, 22, 120)  0           542[0][0]
# __________________________________________________________________________________________________
# 545 (Conv2D)                    (None, 22, 22, 24)   2904        383[0][0]
# __________________________________________________________________________________________________
# 386 (Add)                       (None, 22, 22, 24)   0           545[0][0]
#                                                                  536[0][0]
# __________________________________________________________________________________________________
# 548 (Conv2D)                    (None, 22, 22, 120)  3000        386[0][0]
# __________________________________________________________________________________________________
# 389 (ReLU)                      (None, 22, 22, 120)  0           548[0][0]
# __________________________________________________________________________________________________
# 551_pad (ZeroPadding2D)         (None, 26, 26, 120)  0           389[0][0]
# __________________________________________________________________________________________________
# 551 (DepthwiseConv2D)           (None, 22, 22, 120)  3120        551_pad[0][0]
# __________________________________________________________________________________________________
# 392 (ReLU)                      (None, 22, 22, 120)  0           551[0][0]
# __________________________________________________________________________________________________
# 554 (Conv2D)                    (None, 22, 22, 24)   2904        392[0][0]
# __________________________________________________________________________________________________
# 395 (Add)                       (None, 22, 22, 24)   0           554[0][0]
#                                                                  386[0][0]
# __________________________________________________________________________________________________
# 557 (Conv2D)                    (None, 22, 22, 120)  3000        395[0][0]
# __________________________________________________________________________________________________
# 398 (ReLU)                      (None, 22, 22, 120)  0           557[0][0]
# __________________________________________________________________________________________________
# 560_pad (ZeroPadding2D)         (None, 24, 24, 120)  0           398[0][0]
# __________________________________________________________________________________________________
# 560 (DepthwiseConv2D)           (None, 11, 11, 120)  1200        560_pad[0][0]
# __________________________________________________________________________________________________
# 401 (ReLU)                      (None, 11, 11, 120)  0           560[0][0]
# __________________________________________________________________________________________________
# 563 (Conv2D)                    (None, 11, 11, 40)   4840        401[0][0]
# __________________________________________________________________________________________________
# 566 (Conv2D)                    (None, 11, 11, 240)  9840        563[0][0]
# __________________________________________________________________________________________________
# 406 (ReLU)                      (None, 11, 11, 240)  0           566[0][0]
# __________________________________________________________________________________________________
# 569_pad (ZeroPadding2D)         (None, 17, 17, 240)  0           406[0][0]
# __________________________________________________________________________________________________
# 569 (DepthwiseConv2D)           (None, 11, 11, 240)  12000       569_pad[0][0]
# __________________________________________________________________________________________________
# 409 (ReLU)                      (None, 11, 11, 240)  0           569[0][0]
# __________________________________________________________________________________________________
# 572 (Conv2D)                    (None, 11, 11, 40)   9640        409[0][0]
# __________________________________________________________________________________________________
# 412 (Add)                       (None, 11, 11, 40)   0           572[0][0]
#                                                                  563[0][0]
# __________________________________________________________________________________________________
# 575 (Conv2D)                    (None, 11, 11, 160)  6560        412[0][0]
# __________________________________________________________________________________________________
# 415 (ReLU)                      (None, 11, 11, 160)  0           575[0][0]
# __________________________________________________________________________________________________
# 578_pad (ZeroPadding2D)         (None, 15, 15, 160)  0           415[0][0]
# __________________________________________________________________________________________________
# 578 (DepthwiseConv2D)           (None, 11, 11, 160)  4160        578_pad[0][0]
# __________________________________________________________________________________________________
# 418 (ReLU)                      (None, 11, 11, 160)  0           578[0][0]
# __________________________________________________________________________________________________
# 581 (Conv2D)                    (None, 11, 11, 40)   6440        418[0][0]
# __________________________________________________________________________________________________
# 421 (Add)                       (None, 11, 11, 40)   0           581[0][0]
#                                                                  412[0][0]
# __________________________________________________________________________________________________
# 584 (Conv2D)                    (None, 11, 11, 200)  8200        421[0][0]
# __________________________________________________________________________________________________
# 424 (ReLU)                      (None, 11, 11, 200)  0           584[0][0]
# __________________________________________________________________________________________________
# 587_pad (ZeroPadding2D)         (None, 15, 15, 200)  0           424[0][0]
# __________________________________________________________________________________________________
# 587 (DepthwiseConv2D)           (None, 11, 11, 200)  5200        587_pad[0][0]
# __________________________________________________________________________________________________
# 427 (ReLU)                      (None, 11, 11, 200)  0           587[0][0]
# __________________________________________________________________________________________________
# 590 (Conv2D)                    (None, 11, 11, 48)   9648        427[0][0]
# __________________________________________________________________________________________________
# 593 (Conv2D)                    (None, 11, 11, 240)  11760       590[0][0]
# __________________________________________________________________________________________________
# 432 (ReLU)                      (None, 11, 11, 240)  0           593[0][0]
# __________________________________________________________________________________________________
# 596_pad (ZeroPadding2D)         (None, 17, 17, 240)  0           432[0][0]
# __________________________________________________________________________________________________
# 596 (DepthwiseConv2D)           (None, 11, 11, 240)  12000       596_pad[0][0]
# __________________________________________________________________________________________________
# 435 (ReLU)                      (None, 11, 11, 240)  0           596[0][0]
# __________________________________________________________________________________________________
# 599 (Conv2D)                    (None, 11, 11, 48)   11568       435[0][0]
# __________________________________________________________________________________________________
# 438 (Add)                       (None, 11, 11, 48)   0           599[0][0]
#                                                                  590[0][0]
# __________________________________________________________________________________________________
# 602 (Conv2D)                    (None, 11, 11, 240)  11760       438[0][0]
# __________________________________________________________________________________________________
# 441 (ReLU)                      (None, 11, 11, 240)  0           602[0][0]
# __________________________________________________________________________________________________
# 605_pad (ZeroPadding2D)         (None, 13, 13, 240)  0           441[0][0]
# __________________________________________________________________________________________________
# 605 (DepthwiseConv2D)           (None, 11, 11, 240)  2400        605_pad[0][0]
# __________________________________________________________________________________________________
# 444 (ReLU)                      (None, 11, 11, 240)  0           605[0][0]
# __________________________________________________________________________________________________
# 608 (Conv2D)                    (None, 11, 11, 48)   11568       444[0][0]
# __________________________________________________________________________________________________
# 447 (Add)                       (None, 11, 11, 48)   0           608[0][0]
#                                                                  438[0][0]
# __________________________________________________________________________________________________
# 611 (Conv2D)                    (None, 11, 11, 288)  14112       447[0][0]
# __________________________________________________________________________________________________
# 450 (ReLU)                      (None, 11, 11, 288)  0           611[0][0]
# __________________________________________________________________________________________________
# 614_pad (ZeroPadding2D)         (None, 13, 13, 288)  0           450[0][0]
# __________________________________________________________________________________________________
# 614 (DepthwiseConv2D)           (None, 6, 6, 288)    2880        614_pad[0][0]
# __________________________________________________________________________________________________
# 453 (ReLU)                      (None, 6, 6, 288)    0           614[0][0]
# __________________________________________________________________________________________________
# 617 (Conv2D)                    (None, 6, 6, 96)     27744       453[0][0]
# __________________________________________________________________________________________________
# 620 (Conv2D)                    (None, 6, 6, 480)    46560       617[0][0]
# __________________________________________________________________________________________________
# 458 (ReLU)                      (None, 6, 6, 480)    0           620[0][0]
# __________________________________________________________________________________________________
# 623_pad (ZeroPadding2D)         (None, 12, 12, 480)  0           458[0][0]
# __________________________________________________________________________________________________
# 623 (DepthwiseConv2D)           (None, 6, 6, 480)    24000       623_pad[0][0]
# __________________________________________________________________________________________________
# 461 (ReLU)                      (None, 6, 6, 480)    0           623[0][0]
# __________________________________________________________________________________________________
# 626 (Conv2D)                    (None, 6, 6, 96)     46176       461[0][0]
# __________________________________________________________________________________________________
# 464 (Add)                       (None, 6, 6, 96)     0           626[0][0]
#                                                                  617[0][0]
# __________________________________________________________________________________________________
# 629 (Conv2D)                    (None, 6, 6, 384)    37248       464[0][0]
# __________________________________________________________________________________________________
# 467 (ReLU)                      (None, 6, 6, 384)    0           629[0][0]
# __________________________________________________________________________________________________
# 632_pad (ZeroPadding2D)         (None, 8, 8, 384)    0           467[0][0]
# __________________________________________________________________________________________________
# 632 (DepthwiseConv2D)           (None, 6, 6, 384)    3840        632_pad[0][0]
# __________________________________________________________________________________________________
# 470 (ReLU)                      (None, 6, 6, 384)    0           632[0][0]
# __________________________________________________________________________________________________
# 635 (Conv2D)                    (None, 6, 6, 96)     36960       470[0][0]
# __________________________________________________________________________________________________
# 473 (Add)                       (None, 6, 6, 96)     0           635[0][0]
#                                                                  464[0][0]
# __________________________________________________________________________________________________
# 638 (Conv2D)                    (None, 6, 6, 480)    46560       473[0][0]
# __________________________________________________________________________________________________
# 476 (ReLU)                      (None, 6, 6, 480)    0           638[0][0]
# __________________________________________________________________________________________________
# 641_pad (ZeroPadding2D)         (None, 12, 12, 480)  0           476[0][0]
# __________________________________________________________________________________________________
# 641 (DepthwiseConv2D)           (None, 6, 6, 480)    24000       641_pad[0][0]
# __________________________________________________________________________________________________
# 479 (ReLU)                      (None, 6, 6, 480)    0           641[0][0]
# __________________________________________________________________________________________________
# 644 (Conv2D)                    (None, 6, 6, 160)    76960       479[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 160)          0           644[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160)          640         avg_pool[0][0]
# __________________________________________________________________________________________________
# pred (Dense)                    (None, 10)           1610        batch_normalization[0][0]
# ==================================================================================================
# Total params: 570,970
# Trainable params: 570,650
# Non-trainable params: 320
# __________________________________________________________________________________________________

# %%
model_name = 'mcunet_320_1.h5'
checkpoint = ModelCheckpoint(model_name, save_best_only=True, monitor='val_accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(ds_train,
              epochs=100,
              validation_data=ds_test,
              callbacks=[checkpoint],
              shuffle=True,
              verbose=1)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 109s 106ms/step - loss: 1.1134 - accuracy: 0.6100 - val_loss: 0.9751 - val_accuracy: 0.6571
# DEBUG:h5py._conv:Creating converter from 5 to 3
# Epoch 2/100
# 1000/1000 [==============================] - 107s 107ms/step - loss: 0.6591 - accuracy: 0.7735 - val_loss: 0.7388 - val_accuracy: 0.7497
# Epoch 3/100
# 1000/1000 [==============================] - 107s 107ms/step - loss: 0.5064 - accuracy: 0.8279 - val_loss: 0.5978 - val_accuracy: 0.7941
# Epoch 4/100
# 1000/1000 [==============================] - 106s 106ms/step - loss: 0.4117 - accuracy: 0.8608 - val_loss: 0.6413 - val_accuracy: 0.7891
# Epoch 5/100
# 1000/1000 [==============================] - 105s 105ms/step - loss: 0.3376 - accuracy: 0.8864 - val_loss: 0.6518 - val_accuracy: 0.7915
# Epoch 6/100
# 1000/1000 [==============================] - 106s 106ms/step - loss: 0.2781 - accuracy: 0.9073 - val_loss: 0.7163 - val_accuracy: 0.7811
# Epoch 7/100
#  590/1000 [================>.............] - ETA: 42s - loss: 0.2342 - accuracy: 0.9232

# %%
# new_model = load_model(model_name)
# new_model.evaluate(ds_test)
