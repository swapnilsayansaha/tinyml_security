# %%
#95%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import helpermethods
import tensorflow.compat.v1 as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import numpy as np
import sys
from tensorflow.compat.v1.keras.layers import Dense, Input, RNN
from tensorflow.compat.v1.keras.models import Model, Sequential, load_model
from tensorflow.compat.v1.keras import backend as K
from tensorflow.compat.v1.keras.optimizers import Adam
from tensorflow.compat.v1.keras.callbacks import ModelCheckpoint
from tensorflow.compat.v1.keras.losses import MSE

from tensorflow.python.keras.backend import set_session
config = tf.compat.v1.ConfigProto() 
config.gpu_options.allow_growth = True  
config.log_device_placement = True  
sess2 = tf.compat.v1.Session(config=config)
set_session(sess2) 

tf.disable_eager_execution()
#FastRNN and FastGRNN imports
from rnn import FastGRNNCellKeras, FastRNNCellKeras
from data_utils import *

f = '/home/nesl/209as_sec/human_act/Data/Activity_Dataset/'
model_dir = 'trained_models/'
window_size = 550
stride = 50

X_tr, Y_tr, X_test, Y_test = import_auritus_activity_dataset(dataset_folder = f, 
                                use_timestamp=False, 
                                shuffle=True, 
                                window_size = window_size, stride = stride, 
                                return_test_set = True, test_set_size = 300)
print(X_tr.shape)
print(Y_tr.shape)
print(X_test.shape)
print(Y_test.shape)

Xtrain = X_tr
Ytrain = Y_tr
Xtest = X_test
Ytest = Y_test
numClasses = Y_tr.shape[1]
dataDimension = Xtrain[0].shape
channels = Xtrain.shape[2]

cell = "FastGRNN" # Choose between FastGRNN, FastRNN  ###, UGRNN, GRU and LSTM

inputDims = [window_size, channels] #features taken in by RNN in one timestep
hiddenDims = 32 #hidden state of RNN

totalEpochs = 300
batchSize = 100

learningRate = 0.01
decayStep = 200
decayRate = 0.1

outFile = None #provide your file, if you need all the logging info in a file

#low-rank parameterisation for weight matrices. None => Full Rank
wRank = None 
uRank = None 

#Sparsity of the weight matrices. x => 100*x % are non-zeros
#Note: Sparsity inducing is not supported in this code. 
sW = 1.0 
sU = 1.0

#Non-linearities for the RNN architecture. Can choose from "tanh, sigmoid, relu, quantTanh, quantSigm"
update_non_linearity = "tanh"
gate_non_linearity = "sigmoid"



FastCell = FastGRNNCellKeras(hiddenDims, gate_non_linearity=gate_non_linearity,
                        update_non_linearity=update_non_linearity,
                        wRank=wRank, uRank=uRank)
                        
                        
model = load_model('fastgrnn.h5', custom_objects={'FastGRNNCellKeras':FastCell})
model.compile(run_eagerly=False,experimental_run_tf_function=True,optimizer=Adam(), loss='categorical_crossentropy')
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:21:00.0, compute capability: 8.6
# 100%|█████████████████████████████████████████| 399/399 [00:13<00:00, 29.79it/s]
# (14671, 550, 6)
# (14671, 9)
# (300, 550, 6)
# (300, 9)
# fast_grnn_cell_keras/W/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/Initializer/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/Initializer/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/Initializer/random_normal: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/zeta/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/zeta/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/zeta/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/nu/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/nu/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/nu/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_g/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_g/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_g/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_h/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_h/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_h/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/Shape: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/ExpandDims: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/ExpandDims_1: (ExpandDims): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/transpose: (Transpose): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2: (TensorListReserve): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayUnstack/TensorListFromTensor: (TensorListFromTensor): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_2: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Tanh: (Tanh): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_1: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_2: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_3: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_4: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2_1: (TensorListReserve): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_1: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_2: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_3: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_4: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_5: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_6: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_7: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_8: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_9: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_10: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_11: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_12: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_13: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_14: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_15: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_16: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_17: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_18: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_19: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_20: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_21: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_22: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_23: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_24: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_25: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_26: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_27: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_28: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_29: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_30: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_31: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_32: (EmptyTensorList): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_2: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_3: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_4: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_5: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_6: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_7: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_8: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_9: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_10: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_11: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_12: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_13: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_14: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_15: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_16: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_17: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_18: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_19: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_20: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_21: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_22: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_23: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_24: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_25: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_26: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_27: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_28: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_29: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_30: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_31: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_32: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_33: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_34: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_35: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_36: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_37: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_38: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_39: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_40: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_41: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_42: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_43: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_44: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Identity_45: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2Stack/TensorListStack: (TensorListStack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_3: (StridedSlice): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/transpose_1: (Transpose): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# dense/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# dense/Softmax: (Softmax): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_1: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_2: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_2: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_3: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_3: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_4: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_4: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_5: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_5: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_6: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_6: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp_7: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ReadVariableOp_7: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_1: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_2: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_3: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_4: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_5: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_6: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp_7: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_2: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_3: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_4: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_5: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_6: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_7: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_8: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_9: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_10: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_11: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_12: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_13: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_14: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_15: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_16: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_17: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_18: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_19: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_20: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_21: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_22: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_23: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_24: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_25: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_26: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_27: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_28: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_29: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_30: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_31: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_32: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_33: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_34: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_35: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_36: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_37: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_38: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_39: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_40: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_41: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_42: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_43: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_44: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_45: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_46: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/enter/_47: (Enter): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_48: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_49: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_50: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_51: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_52: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_53: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_54: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_55: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_56: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_57: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_58: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_59: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_60: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_61: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_62: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_63: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_64: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_65: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_66: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_67: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_68: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_69: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_70: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_71: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_72: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_73: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_74: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_75: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_76: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_77: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_78: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_79: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_80: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_81: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_82: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_83: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_84: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_85: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_86: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/merge/_87: (Merge): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/LoopCond/_88: (LoopCond): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/loop_counter_switch/_89: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/maximum_iterations_switch/_90: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/time_switch/_91: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/TensorArrayV2_1_switch/_92: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/FastGRNNCellKerasZeroState/zeros_switch/_93: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/strided_slice_1_switch/_94: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/TensorArrayUnstack/TensorListFromTensor_switch/_95: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_switch/_96: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_1_switch/_97: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_2_switch/_98: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_3_switch/_99: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_4_switch/_100: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_5_switch/_101: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_6_switch/_102: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_7_switch/_103: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_8_switch/_104: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_9_switch/_105: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_10_switch/_106: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_11_switch/_107: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_12_switch/_108: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_13_switch/_109: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_14_switch/_110: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_15_switch/_111: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_16_switch/_112: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_17_switch/_113: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_18_switch/_114: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_19_switch/_115: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_20_switch/_116: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_21_switch/_117: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_22_switch/_118: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_23_switch/_119: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_24_switch/_120: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_25_switch/_121: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_26_switch/_122: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_27_switch/_123: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_28_switch/_124: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_29_switch/_125: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_30_switch/_126: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_31_switch/_127: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/rnn/while/EmptyTensorList_32_switch/_128: (Switch): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/loop_body_control/_129: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_130: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_131: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_132: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_133: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_134: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_135: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_136: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_137: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_138: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_139: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_140: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_141: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_142: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_143: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_144: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_145: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_146: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_147: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_148: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_149: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_150: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_151: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_152: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_153: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_154: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_155: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_156: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_157: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_158: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_159: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_160: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_161: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_162: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_163: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_164: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_165: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_166: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_167: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_168: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/exit/_169: (Exit): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/LoopExecuted/_170: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while: (IdentityN): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_171: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_172: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_173: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_174: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_175: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_176: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_177: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_178: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_179: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_180: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_181: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_182: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_183: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_184: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_185: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_186: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_187: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_188: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_189: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_190: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_191: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_192: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_193: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_194: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_195: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_196: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_197: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_198: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_199: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_200: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_201: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_202: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_203: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_204: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_205: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_206: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_207: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_208: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_209: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/next_iteration/_210: (NextIteration): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input_control_node/_211: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/cond/_0/Less: (Less): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_212: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_213: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_214: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_215: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_216: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_217: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_218: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_219: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_220: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_221: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_222: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_223: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_224: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_225: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_226: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_227: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_228: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_229: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_230: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_231: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_232: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_233: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_234: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_235: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_236: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_237: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_238: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_239: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_240: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_241: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_242: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_243: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_244: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_245: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_246: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_247: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_248: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_249: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_250: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_251: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_252: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_253: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_254: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_255: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_256: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/input/_257: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/output/_258: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/cond/_0/output_control_node/_259: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/cond/_0: (IdentityN): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input_control_node/_260: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorArrayV2Read/TensorListGetItem: (TensorListGetItem): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Tanh: (Tanh): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_1/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_1: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_2/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/Sigmoid_2: (Sigmoid): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_3: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/add_4: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorArrayV2Write/TensorListSetItem: (TensorListSetItem): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/add_0: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/add_1_0: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_1: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_2: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_3: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_4: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_5: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_6: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_7: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_8: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_9: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_10: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_11: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_12: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_13: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_14: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_15: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_16: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_17: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_18: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_19: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_20: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_21: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_22: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_23: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_24: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_25: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_26: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_27: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_28: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_29: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_30: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_31: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorListPushBack_32: (TensorListPushBack): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_261: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_262: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_263: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_264: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_265: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_266: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_267: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_268: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_269: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_270: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_271: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_272: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_273: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_274: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_275: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_276: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_277: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_278: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# Func/rnn/while/body/_1/input/_279: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# rnn/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/ExpandDims/dim: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/concat/axis: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/ExpandDims_1/dim: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/FastGRNNCellKerasZeroState/Const_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/transpose/perm: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_1/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_1/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_1/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayUnstack/TensorListFromTensor/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_2/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_2/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_2/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/fast_grnn_cell_keras_2/fast_grnn_cell_keras/sub/x: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2_1/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/time: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/maximum_iterations: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/loop_counter: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_1/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_2/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_3/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_3/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_4/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_4/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_5/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_5/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_6/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_6/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_7/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_7/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_8/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_8/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_9/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_9/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_10/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_10/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_11/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_11/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_12/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_12/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_13/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_13/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_14/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_14/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_15/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_15/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_16/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_16/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_17/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_17/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_18/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_18/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_19/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_19/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_3: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_20/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_21/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_21/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_22/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_22/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_23/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_23/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_24/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_24/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_25/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_25/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_26/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_26/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_27/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_27/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_4: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_28/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_5: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_29/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_6: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_30/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_7: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_31/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/Const_8: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/EmptyTensorList_32/max_num_elements: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/TensorArrayV2Stack/TensorListStack/element_shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_3/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_3/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/strided_slice_3/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/transpose_1/perm: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/min: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/max: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_1: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_2: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_3: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_4: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_5: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_6: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_7: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# total/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# count/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense_target: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# metrics/accuracy/ArgMax/dimension: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# metrics/accuracy/ArgMax_1/dimension: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# metrics/accuracy/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Rank: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Rank_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Sub/y: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Slice/size: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/concat/values_0: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/concat/axis: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Rank_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Sub_1/y: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Slice_1/size: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/concat_1/values_0: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/concat_1/axis: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Sub_2/y: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/softmax_cross_entropy_with_logits/Slice_2/begin: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/weighted_loss/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/Const_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/Rank: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/range/start: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/dense_loss/range/delta: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# loss/mul/x: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# iter/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# beta_1/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# beta_2/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# decay/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# learning_rate/Initializer/initial_value: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/m/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/m/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/zeta/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/nu/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_g/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_h/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/m/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/W/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/v/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/U/v/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/zeta/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/nu/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_g/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# fast_grnn_cell_keras/B_h/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/v/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_8: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_9: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_10: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_11: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_12: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_13: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_14: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_15: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_16: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_17: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_18: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_19: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_20: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_21: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_22: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_23: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# Placeholder_24: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# rnn/while/body/_1/TensorArrayV2Read/TensorListGetItem/element_shape: (Const): /job:localhost/replica:0/ta

# %%
def pgd_attack(model,iterations, image, label, alpha, eps):
    gen_img = tf.identity(image)
    gen_img = tf.cast(gen_img,dtype=tf.dtypes.float32)
    gen_img = gen_img + tf.random.uniform(gen_img.get_shape().as_list(), minval=-eps, 
                                          maxval=eps, dtype=tf.dtypes.float32)
    x_temp = image
    for iter in range(iterations):
        #imgv = tf.Variable(gen_img)
        imgv = image
        with tf.GradientTape() as tape:
            tape.watch(imgv)
            predictions = model(imgv)
            loss = tf.keras.losses.CategoricalCrossentropy()(label, predictions)
            grads = tape.gradient(loss,imgv)
        signed_grads = tf.sign(grads)
        gen_img = gen_img + (alpha*signed_grads)
        gen_img = tf.clip_by_value(gen_img, image-eps, image+eps)
    return gen_img
        

item = 0.1
al = 0.1
iterations = 5

countadv = 0
for i in range(len(Xtest)):
    act = Xtest[i,:,:].reshape(1,550,6)
    label = Ytest[i,:].reshape(1,9)
    actPred = model.predict(act)
    actPred = actPred.argmax()
    adversary = pgd_attack(model,iterations,act, label, alpha=al, eps=item)
    pred = model.predict(adversary,steps=1,verbose=False)
    adversaryPred = pred[0].argmax()
    if actPred == adversaryPred:
    	countadv += 1

print("Adversarial accuracy : ", countadv / len(X_test))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1879   try:
# -> 1880     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1881   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Inconsistent values for attr 'T' [DT_INT32, DT_INT32, DT_INT32, DT_VARIANT, DT_FLOAT, DT_INT32, DT_VARIANT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT] vs. [DT_INT32, DT_INT32, DT_INT32, DT_VARIANT, DT_FLOAT, DT_INT32, DT_VARIANT, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT] while building NodeDef 'model/rnn/while_Variable_1' using Op<name=While; signature=input: -> output:; attr=T:list(type),min=0; attr=cond:func; attr=body:func; attr=output_shapes:list(shape),default=[]; attr=parallel_iterations:int,default=10; is_stateful=true>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1442137/1741461038.py in <module>
#      28     actPred = model.predict(act)
#      29     actPred = actPred.argmax()
# ---> 30     adversary = pgd_attack(model,iterations,act, label, alpha=al, eps=item)
#      31     pred = model.predict(adversary,steps=1,verbose=False)
#      32     adversaryPred = pred[0].argmax()
#
# /tmp/ipykernel_1442137/1741461038.py in pgd_attack(model, iterations, image, label, alpha, eps)
#       6     x_temp = image
#       7     for iter in range(iterations):
# ----> 8         imgv = tf.Variable(gen_img)
#       9         with tf.GradientTape() as tape:
#      10             tape.watch(imgv)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     204     if aggregation is None:
#     205       aggregation = VariableAggregation.NONE
# --> 206     return previous_getter(
#     207         initial_value=initial_value,
#     208         trainable=trainable,
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2610   if use_resource:
#    2611     distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2612     return resource_variable_ops.ResourceVariable(
#    2613         initial_value=initial_value,
#    2614         trainable=trainable,
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1582       self._init_from_proto(variable_def, import_scope=import_scope)
#    1583     else:
# -> 1584       self._init_from_args(
#    1585           initial_value=initial_value,
#    1586           trainable=trainable,
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1766                   gen_resource_variable_ops.assign_variable_op(
#    1767                       handle,
# -> 1768                       variables._try_guard_against_uninitialized_dependencies(
#    1769                           name, initial_value),
#    1770                       name=n))
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _try_guard_against_uninitialized_dependencies(name, initial_value)
#    2765   if _has_cycle(initial_value.op, state={}):
#    2766     return initial_value
# -> 2767   return _safe_initial_value_from_tensor(name, initial_value, op_cache={})
#    2768
#    2769
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2840   new_op_inputs = []
#    2841   for op_input in op.inputs:
# -> 2842     new_op_input = _safe_initial_value_from_tensor(name, op_input, op_cache)
#    2843     new_op_inputs.append(new_op_input)
#    2844     modified = modified or (new_op_input != op_input)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_tensor(name, tensor, op_cache)
#    2805   new_op = op_cache.get(op.name)
#    2806   if new_op is None:
# -> 2807     new_op = _safe_initial_value_from_op(name, op, op_cache)
#    2808     op_cache[op.name] = new_op
#    2809   return new_op.outputs[tensor.value_index]
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in _safe_initial_value_from_op(name, op, op_cache)
#    2851     new_op_name = op.node_def.name + "_" + name
#    2852     new_op_name = new_op_name.replace(":", "_")
# -> 2853     return op.graph.create_op(
#    2854         new_op_type,
#    2855         new_op_inputs,
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     533                 'in a future version' if date is None else ('after %s' % date),
#     534                 instructions)
# --> 535       return func(*args, **kwargs)
#     536
#     537     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3493       if not isinstance(a, Tensor):
#    3494         raise TypeError("Input #%d is not a tensor: %s" % (idx, a))
# -> 3495     return self._create_op_internal(op_type, inputs, dtypes, input_types, name,
#    3496                                     attrs, op_def, compute_device)
#    3497
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3555     # Session.run call cannot occur between creating and mutating the op.
#    3556     with self._mutation_lock():
# -> 3557       ret = Operation(
#    3558           node_def,
#    3559           self,
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2039       if op_def is None:
#    2040         op_def = self._graph._get_op_def(node_def.op)
# -> 2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#
# ~/swapnil_debug/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1881   except errors.InvalidArgumentError as e:
#    1882     # Convert to ValueError for backwards compatibility.
# -> 1883     raise ValueError(str(e))
#    1884
#    1885   return c_op
#
# ValueError: Inconsistent values for attr 'T' [DT_INT32, DT_INT32, DT_INT32, DT_VARIANT, DT_FLOAT, DT_INT32, DT_VARIANT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT] vs. [DT_INT32, DT_INT32, DT_INT32, DT_VARIANT, DT_FLOAT, DT_INT32, DT_VARIANT, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_RESOURCE, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT, DT_VARIANT] while building NodeDef 'model/rnn/while_Variable_1' using Op<name=While; signature=input: -> output:; attr=T:list(type),min=0; attr=cond:func; attr=body:func; attr=output_shapes:list(shape),default=[]; attr=parallel_iterations:int,default=10; is_stateful=true>
